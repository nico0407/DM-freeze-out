# %%
import matplotlib.pyplot as plt
import csv
import numpy as np

# %%
X, G = np.loadtxt('dofdata/gstarSteigmanQCDFine.txt', delimiter=' ', unpack=True)

# %%
plt.plot(X, G, label='g_star Steigman QCD Fine',color = "black")
plt.title('g_star Steigman QCD Fine')
plt.xlabel('T [GeV]')
plt.ylabel('g_star')
plt.xscale('log')
plt.yscale('log')
plt.legend()
plt.grid(which='major')
plt.grid(which='minor', axis='y',linestyle='--')
plt.show()

# %% [markdown]
# ![g_star.png](attachment:g_star.png)

# %%
from scipy import optimize
import pandas as pd

# %%
d = {'T':X,'g_star':G}

# %%
df = pd.DataFrame(d)

# %%
df
# Out:
#                T      g_star
# 0       0.001031   10.391061
# 1       0.001144   10.391061
# 2       0.001277   10.391061
# 3       0.001392   10.446927
# 4       0.001516   10.446927
# ..           ...         ...
# 246  4109.770190  105.530726
# 247  4422.869883  105.530726
# 248  4818.426358  105.530726
# 249  5412.431122  105.530726
# 250  5718.832171  105.530726
#
# [251 rows x 2 columns]

# %%
data = np.loadtxt("dofdata/gstarSteigmanQCDFine.txt",delimiter = ' ')
#data = np.loadtxt("test4multiplot.txt", dtype = str)     #if file contains multiple data types
#data
temp = data[:,0]
gstar = data[:,1]
#plot data
plt.figure(figsize = [10,6])
plt.plot(temp,gstar,"o", color = "red", label = "Test data", markersize=4)
plt.title("g_star behaviour", fontsize=16)
plt.xlabel('T [GeV]', fontsize=14)
plt.ylabel('g_star', fontsize=14)
plt.legend()
plt.hlines(10.8,0.0001,100000,color='black', linestyle='dashed',linewidth=1)
plt.hlines(19,0.0001,100000,color='black', linestyle='dashed',linewidth=1)
plt.hlines(50,0.0001,100000,color='black', linestyle='dashed',linewidth=1)
plt.hlines(84,0.0001,100000,color='black', linestyle='dashed',linewidth=1)
plt.hlines(103,0.0001,100000,color='black', linestyle='dashed',linewidth=1)
plt.hlines(105.5,0.0001,100000,color='black', linestyle='dashed',linewidth=1)
plt.vlines(0.017,0,120,color='black', linestyle='dashed',linewidth=1)
plt.vlines(0.12,0,120,color='black', linestyle='dashed',linewidth=1)
plt.vlines(0.23,0,120,color='black', linestyle='dashed',linewidth=1)
plt.vlines(9.38,0,120,color='black', linestyle='dashed',linewidth=1)
plt.vlines(100,0,120,color='black', linestyle='dashed',linewidth=1)
plt.vlines(5718,0,120,color='black', linestyle='dashed',linewidth=1)
plt.ylim(9,120)
plt.xlim(5*1E-4,20000)
plt.xscale('log')
plt.yscale('log')
plt.grid(True)                                 # comment this if u do not need grid
plt.show()

# %%
temp1 = data[0:32,0]
#print(x1)
temp2 = data[32:56,0]
#print(x2)
temp3 = data[56:100,0]
#print(x3)
temp4 = data[100:168,0]
#print(x3)
temp6 = data[168:217,0]
#print(x4)
temp5 = data[217:250,0]
#print(x5)

gstar1 = data[0:32,1]
#print(x1)
gstar2 = data[32:56,1]
#print(x2)
gstar3 = data[56:100,1]
#print(x3)
gstar4 = data[100:168,1]
#print(x3)
gstar6 = data[168:217,1]
#print(x4)
gstar5 = data[217:250,1]
#print(x5)

# %%
print(temp1)
print(temp2)
print(temp3)
print(temp4)
print(temp6)
print(temp5)
# Out:
# [0.00103107 0.00114409 0.00127729 0.00139152 0.00151597 0.00171331
#  0.00191278 0.00210951 0.00235511 0.0026293  0.00295344 0.00337899
#  0.00377239 0.00405979 0.0045048  0.00487775 0.00518551 0.00558057
#  0.00589649 0.00654284 0.00726004 0.00776548 0.00840838 0.0091045
#  0.00973835 0.01022688 0.01080583 0.01170043 0.01282508 0.01388686
#  0.01540908 0.01668479]
# [0.01874165 0.0205431  0.02265591 0.02483361 0.02688956 0.02929441
#  0.03171967 0.03476857 0.03787808 0.04177375 0.04578906 0.05049836
#  0.05501464 0.06030268 0.06569581 0.07157127 0.07749658 0.08289187
#  0.08920693 0.09600309 0.10143788 0.10587678 0.11187053 0.11748257]
# [0.12337614 0.12877504 0.13359033 0.13774033 0.14201925 0.14553789
#  0.14823397 0.15377688 0.15662559 0.16050612 0.16448279 0.16959247
#  0.17063329 0.17168051 0.17379426 0.17486088 0.17593404 0.17810016
#  0.18029295 0.18139945 0.18363286 0.18475986 0.18475986 0.18818252
#  0.19049944 0.19402843 0.19641733 0.19883565 0.19883565 0.20251906
# ...

# %%
print(gstar1)
print(gstar2)
print(gstar3)
print(gstar4)
print(gstar6)
print(gstar5)
# Out:
# [10.39106145 10.39106145 10.39106145 10.44692737 10.44692737 10.44692737
#  10.44692737 10.44692737 10.44692737 10.5027933  10.5027933  10.5027933
#  10.55865922 10.55865922 10.55865922 10.61452514 10.61452514 10.61452514
#  10.61452514 10.61452514 10.67039106 10.61452514 10.61452514 10.61452514
#  10.61452514 10.61452514 10.61452514 10.61452514 10.67039106 10.67039106
#  10.67039106 10.72625698]
# [11.00558659 11.2849162  11.56424581 11.84357542 12.12290503 12.34636872
#  12.68156425 13.12849162 13.46368715 13.79888268 14.18994413 14.63687151
#  14.91620112 15.30726257 15.58659218 15.92178771 16.31284916 16.53631285
#  16.70391061 17.15083799 17.48603352 17.98882682 18.43575419 18.93854749]
# [19.32960894 20.         20.55865922 21.11731844 22.06703911 22.84916201
#  23.57541899 24.41340782 25.1396648  25.81005587 26.59217877 27.26256983
#  27.82122905 28.37988827 28.88268156 29.44134078 30.16759777 30.78212291
# ...

# %%
temp[32]
# Out:
# 0.01874164876284413

# %%
temp[56]
# Out:
# 0.1233761398411089

# %%
temp[100]
# Out:
# 0.23169929488609683

# %%
temp[168]
# Out:
# 9.387329727864389

# %%
temp[217]
# Out:
# 178.10015797967904

# %%
temp[250]
# Out:
# 5718.8321713429

# %%
def lin1(t,a1,a2,a3):
    return a1+a2*t+ a3*t**2

# %%
popt1,pcov1 = optimize.curve_fit(lin1,temp1,gstar1,p0=(0,0,0))

# %%
popt1
# Out:
# array([   10.37860368,    44.41674668, -1656.4724049 ])

# %%
def g_star1(t): 
    return lin1(t,a1=popt1[0],a2=popt1[1],a3=popt1[2])

# %%
#t=np.logspace(np.log10(1E-3),np.log10(1E-1))
t1=np.linspace(0.00103107,0.01668479, 1000)
plt.semilogx(temp1,gstar1,'ro', markersize=4) #semilogx Make a plot with log scaling on the x axis.
plt.plot(t1,g_star1(t),color = "black" )   #BUT THAT WASN'T THE PHASE SPACE FUNCTION? SO THIS PLOT ISN'T REFERRING TO THAT? NO, IS G STAR SQUARED BUT HOW?!
plt.xlabel('$T$ [GeV]',size=15)
plt.ylabel(r'$g_*$',size=15)

plt.title('parametrization of the $g_*$', size= 15)
#plt.legend()
plt.grid()

# %%
def lin2(t,a4,a5,a6):
    return a4+a5*t+ a6*t**2

# %%
popt2,pcov2 = optimize.curve_fit(lin2,temp2,gstar2,p0=(0,0,0))

# %%
popt2
# Out:
# array([   9.10908676,  122.61245237, -366.57202888])

# %%
def g_star2(t):
    return lin2(t,a4=popt2[0],a5=popt2[1],a6=popt2[2])

# %%
#t=np.logspace(np.log10(1E-3),np.log10(1E-1))
t2=np.linspace(0.01874165,0.11748257, 1000)
plt.semilogx(temp2,gstar2,'ro', markersize=4) #semilogx Make a plot with log scaling on the x axis.
plt.plot(t2,g_star2(t2),color = "black" )   #BUT THAT WASN'T THE PHASE SPACE FUNCTION? SO THIS PLOT ISN'T REFERRING TO THAT? NO, IS G STAR SQUARED BUT HOW?!
plt.xlabel('$T$ [GeV]',size=15)
plt.ylabel(r'$g_*$',size=15)

plt.title('parametrization of the $g_*$', size= 15)
#plt.legend()
plt.grid()

# %%
def lin3(t,a7,a8,a9):
    return a7+a8*t+ a9*t**2

# %%
popt3,pcov3 = optimize.curve_fit(lin3,temp3,gstar3,p0=(0,0,0))

# %%
popt3
# Out:
# array([  24.23107196, -219.74347911, 1439.42995816])

# %%
def g_star3(t):
    return lin3(t,a7=popt3[0],a8=popt3[1],a9=popt3[2])

# %%
#t=np.logspace(np.log10(1E-3),np.log10(1E-1))
t3=np.linspace(0.12337614,0.22748515, 1000)
plt.semilogx(temp3,gstar3,'ro', markersize=4) #semilogx Make a plot with log scaling on the x axis.
plt.plot(t3,g_star3(t3),color = "black" )   #BUT THAT WASN'T THE PHASE SPACE FUNCTION? SO THIS PLOT ISN'T REFERRING TO THAT? NO, IS G STAR SQUARED BUT HOW?!
plt.xlabel('$T$ [GeV]',size=15)
plt.ylabel(r'$g_*$',size=15)

plt.title('parametrization of the $g_*$', size= 15)
#plt.legend()
plt.grid()

# %%
def lin4(t,a10,a11,a12,a18):
    return a10+a11*t+ a12*t**2 +a18*t**3

# %%
popt4,pcov4 = optimize.curve_fit(lin4,temp4,gstar4,p0=(0,0,0,0))

# %%
popt4
# Out:
# array([50.17078457, 28.18470272, -6.5344422 ,  0.4420229 ])

# %%
def g_star4(t):
    return lin4(t,a10=popt4[0],a11=popt4[1],a12=popt4[2],a18=popt4[3])

# %%
#t=np.logspace(np.log10(1E-3),np.log10(1E-1))
t4=np.linspace(0.23169929,8.61670073, 1000)
plt.semilogx(temp4,gstar4,'ro', markersize=4) #semilogx Make a plot with log scaling on the x axis.
plt.plot(t4,g_star4(t4),color = "black" )   #BUT THAT WASN'T THE PHASE SPACE FUNCTION? SO THIS PLOT ISN'T REFERRING TO THAT? NO, IS G STAR SQUARED BUT HOW?!
plt.xlabel('$T$ [GeV]',size=15)
plt.ylabel(r'$g_*$',size=15)

plt.title('parametrization of the $g_*$', size= 15)
#plt.legend()
plt.grid()

# %%
def lin6(t,a15,a16,a17):
    return a15+a16*t+ a17*t**2

# %%
popt6,pcov6 = optimize.curve_fit(lin6,temp6,gstar6,p0=(0,0,0))

# %%
popt6
# Out:
# array([ 8.04239785e+01,  3.75753023e-01, -1.43230640e-03])

# %%
def g_star6(t):
    return lin6(t,a15=popt6[0],a16=popt6[1],a17=popt6[2])

# %%
#t=np.logspace(np.log10(1E-3),np.log10(1E-1))
t6=np.linspace(9.38732973,162.4822869, 1000)
plt.semilogx(temp6,gstar6,'ro', markersize=4) #semilogx Make a plot with log scaling on the x axis.
plt.plot(t6,g_star6(t6),color = "black" )   #BUT THAT WASN'T THE PHASE SPACE FUNCTION? SO THIS PLOT ISN'T REFERRING TO THAT? NO, IS G STAR SQUARED BUT HOW?!
plt.xlabel('$T$ [GeV]',size=15)
plt.ylabel(r'$g_*$',size=15)

plt.title('parametrization of the $g_*$', size= 15)
#plt.legend()
plt.grid()

# %%
def lin5(t,a13,a14):
    return a13+a14*t#+ a15*t**2

# %%
popt5,pcov5 = optimize.curve_fit(lin5,temp5,gstar5,p0=(0,0))

# %%
popt5
# Out:
# array([1.05470885e+02, 9.82116227e-06])

# %%
def g_star5(t):
    return lin5(t,a13=popt5[0],a14=popt5[1])#,a15=popt5[2])

# %%
#t=np.logspace(np.log10(1E-3),np.log10(1E-1))
t5=np.linspace(178.10015798,5412.43112233, 1000)
plt.semilogx(temp5,gstar5,'ro', markersize=4) #semilogx Make a plot with log scaling on the x axis.
plt.plot(t5,g_star5(t5),color = "black" )   #BUT THAT WASN'T THE PHASE SPACE FUNCTION? SO THIS PLOT ISN'T REFERRING TO THAT? NO, IS G STAR SQUARED BUT HOW?!
plt.xlabel('$T$ [GeV]',size=15)
plt.ylabel(r'$g_*$',size=15)

plt.title('parametrization of the $g_*$', size= 15)
#plt.legend()
plt.grid()

# %%
plt.semilogx(temp1,gstar1,'ro', markersize=2)
plt.semilogx(temp2,gstar2,'ro', markersize=2)
plt.semilogx(temp3,gstar3,'ro', markersize=2)
plt.semilogx(temp4,gstar4,'ro', markersize=2)
plt.semilogx(temp6,gstar6,'ro', markersize=2)
plt.semilogx(temp5,gstar5,'ro', markersize=2)
plt.plot(t1,g_star1(t1),color = "black" )
plt.plot(t2,g_star2(t2),color = "black" )
plt.plot(t3,g_star3(t3),color = "black" )
plt.plot(t4,g_star4(t4),color = "black" )
plt.plot(t6,g_star6(t6),color = "black" )
plt.plot(t5,g_star5(t5),color = "black" )
plt.xlabel('$T$ [GeV]',size=15)
plt.ylabel(r'$g_*^{1/2}$',size=15)
plt.yscale('log')

plt.title('parametrization of the $g_*$', size= 15)

plt.grid(which='major')
plt.grid(which='minor', axis='y',linestyle='--')

# %%
from scipy import integrate

# %%
# parameters
m = 100                                #GeV DM Mass
Mp = 1.22e19                            #GeV Planck Mass

# %% [markdown]
# $$\frac{dY}{dx}=- \Bigl(\frac{45}{\pi M_P^2}\Bigr)^{-1/2} \frac{g_*^{1/2}m}{x^2} \langle\sigma v\rangle(Y^2-Y_{eq}^2)$$

# %%
def Yeq(x):
    return 0.145*x**(3/2)*np.exp(-x)

# %%
global k
k=1
fk=lambda sigmav: np.sqrt(np.pi*(Mp**2)/45)*m*sigmav  #starting to build the dY/dx

def BEx(x,m=100):
    T=m/x
    if T< 0.00103107:
        return k*np.sqrt(g_star1(T))/x**2   #missing piece of the formula.
    elif 0.01874165<T<0.11748257:
        return k*np.sqrt(g_star2(T))/x**2
    elif 0.12337614<T<0.22748515:
        return k*np.sqrt(g_star3(T))/x**2
    elif 0.23169929<T<105.25139665:
        return k*np.sqrt(g_star4(T))/x**2
    else:
        return k*np.sqrt(g_star5(T))/x**2

# %%
def BE(Y,x):
    return -(Y**2-Yeq(x)**2)*BEx(x)   #putting together the things to have the right formula

#THESE FUNCTIONS HAVE BEEN CREATED TO ACHIVE THE COMPLETE FORMULA FOR THE dY/dx

# %%
xx=np.logspace(np.log10(1),np.log10(1000),1000)
plt.loglog(xx,Yeq(xx),'m',label=r'$Y_{\rm eq}$')




k=fk(sigmav=1E-18)  
x=np.logspace(np.log10(1),np.log10(1000),10000)
Y=integrate.odeint(BE,Yeq(x[0]),x)
plt.loglog(x,Y,'r--',label=r'$\langle \sigma v \rangle = 10^{-18}\ {\rm GeV}^{-2}$')

k=fk(sigmav=1E-17)
Y=integrate.odeint(BE,Yeq(x[0]),x)
plt.loglog(x,Y,'k:')

k=fk(sigmav=1E-16)
Y=integrate.odeint(BE,Yeq(x[0]),x)
plt.loglog(x,Y,'k:')

k=fk(sigmav=1E-15)
Y=integrate.odeint(BE,Yeq(x[0]),x)
plt.loglog(x,Y,'k:')

k=fk(sigmav=1E-14)
Y=integrate.odeint(BE,Yeq(x[0]),x)
plt.loglog(x,Y,'k:')

k=fk(sigmav=1E-13)
Y=integrate.odeint(BE,Yeq(x[0]),x)
plt.loglog(x,Y,'k:')

k=fk(sigmav=1E-12)
Y=integrate.odeint(BE,Yeq(x[0]),x)
plt.loglog(x,Y,'k:')

k=fk(sigmav=1E-11)
Y=integrate.odeint(BE,Yeq(x[0]),x)
plt.loglog(x,Y,'k:')



#WHAT HAPPENS WHEN THE AVERAGE CROSS SECTION*VELOCITY DROPS BELOW 1E-11?!?!?!?!?!?!?




plt.hlines(1E-11,1,1000,linestyles='-',color='g',lw=2,label='$Y_0$')    #THAT'S THE HORIZONTAL LINE IN PURPLE. 
                                                                #REFERS TO THE RIGHT EXPERIMENTAL ABOUNDANCE  


plt.ylim(1E-14,1)
plt.xlim(1,1000)
plt.xlabel('$x = m/T$', size= 15)
plt.ylabel('$Y$', size= 15)
plt.title('$m = 100$ GeV', size= 15)
plt.legend()
plt.grid()

# x grows in time means that the temperature decrease
# Out:
#  lsoda--  at t (=r1) and step size h (=r2), the
#        corrector convergence failed repeatedly
#        or with abs(h) = hmin
#       in above,  r1 =  0.1000000000000D+01   r2 =  0.4659837048118D-09
