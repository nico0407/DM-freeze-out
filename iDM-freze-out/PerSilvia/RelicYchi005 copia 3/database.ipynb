# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
m1variation=[]
mS0=[]
gX=[]
epsilondark=[]
lambdaphih=[]
Ychi=[]
m1=0.05

# %%
for i in range(300):
    m1variation.append(m1+(0.01*i))
    mS0.append(1)
    gX.append(2.213)
    epsilondark.append(0.001)
    #lambdaphih.append(2)
    lambdaphih.append('{:.10f}'.format(0.00000045))
    #Ychi.append(0.005)
    Ychi.append(0.2)

# %%
m1variation
# Out:
# [0.05,
#  0.060000000000000005,
#  0.07,
#  0.08,
#  0.09,
#  0.1,
#  0.11,
#  0.12000000000000001,
#  0.13,
#  0.14,
#  0.15000000000000002,
#  0.16,
#  0.16999999999999998,
#  0.18,
#  0.19,
#  0.2,
#  0.21000000000000002,
#  0.22000000000000003,
#  0.22999999999999998,
#  0.24,
#  0.25,
#  0.26,
#  0.27,
#  0.28,
#  0.29,
#  0.3,
#  0.31,
#  0.32,
#  0.33,
#  0.33999999999999997,
#  0.35,
#  0.36,
#  0.37,
#  0.38,
#  0.39,
#  0.4,
#  0.41,
#  0.42,
#  0.43,
#  0.44,
#  0.45,
#  0.46,
#  0.47,
#  0.48,
#  0.49,
#  0.5,
#  0.51,
#  0.52,
#  0.53,
#  0.54,
#  0.55,
#  0.56,
#  0.5700000000000001,
#  0.5800000000000001,
#  0.5900000000000001,
#  0.6000000000000001,
#  0.6100000000000001,
#  0.6200000000000001,
#  0.63,
#  0.64,
#  0.65,
#  0.66,
#  0.67,
#  0.68,
#  0.6900000000000001,
#  0.7000000000000001,
#  0.7100000000000001,
#  0.7200000000000001,
#  0.7300000000000001,
#  0.7400000000000001,
#  0.7500000000000001,
#  0.76,
#  0.77,
#  0.78,
#  0.79,
#  0.8,
#  0.81,
# ...

# %%
m1step=np.array(m1variation)
mS0step=np.array(mS0)
gXstep=np.array(gX)
epsilondarkstep=np.array(epsilondark)
lambdaphihstep=np.array(lambdaphih)
Ychistep=np.array(Ychi)

# %%
m1step
# Out:
# array([0.05, 0.06, 0.07, 0.08, 0.09, 0.1 , 0.11, 0.12, 0.13, 0.14, 0.15,
#        0.16, 0.17, 0.18, 0.19, 0.2 , 0.21, 0.22, 0.23, 0.24, 0.25, 0.26,
#        0.27, 0.28, 0.29, 0.3 , 0.31, 0.32, 0.33, 0.34, 0.35, 0.36, 0.37,
#        0.38, 0.39, 0.4 , 0.41, 0.42, 0.43, 0.44, 0.45, 0.46, 0.47, 0.48,
#        0.49, 0.5 , 0.51, 0.52, 0.53, 0.54, 0.55, 0.56, 0.57, 0.58, 0.59,
#        0.6 , 0.61, 0.62, 0.63, 0.64, 0.65, 0.66, 0.67, 0.68, 0.69, 0.7 ,
#        0.71, 0.72, 0.73, 0.74, 0.75, 0.76, 0.77, 0.78, 0.79, 0.8 , 0.81,
#        0.82, 0.83, 0.84, 0.85, 0.86, 0.87, 0.88, 0.89, 0.9 , 0.91, 0.92,
#        0.93, 0.94, 0.95, 0.96, 0.97, 0.98, 0.99, 1.  , 1.01, 1.02, 1.03,
#        1.04, 1.05, 1.06, 1.07, 1.08, 1.09, 1.1 , 1.11, 1.12, 1.13, 1.14,
#        1.15, 1.16, 1.17, 1.18, 1.19, 1.2 , 1.21, 1.22, 1.23, 1.24, 1.25,
#        1.26, 1.27, 1.28, 1.29, 1.3 , 1.31, 1.32, 1.33, 1.34, 1.35, 1.36,
#        1.37, 1.38, 1.39, 1.4 , 1.41, 1.42, 1.43, 1.44, 1.45, 1.46, 1.47,
# ...

# %%
lambdaphihstep
# Out:
# array(['0.0000004500', '0.0000004500', '0.0000004500', '0.0000004500',
#        '0.0000004500', '0.0000004500', '0.0000004500', '0.0000004500',
#        '0.0000004500', '0.0000004500', '0.0000004500', '0.0000004500',
#        '0.0000004500', '0.0000004500', '0.0000004500', '0.0000004500',
#        '0.0000004500', '0.0000004500', '0.0000004500', '0.0000004500',
#        '0.0000004500', '0.0000004500', '0.0000004500', '0.0000004500',
#        '0.0000004500', '0.0000004500', '0.0000004500', '0.0000004500',
#        '0.0000004500', '0.0000004500', '0.0000004500', '0.0000004500',
#        '0.0000004500', '0.0000004500', '0.0000004500', '0.0000004500',
#        '0.0000004500', '0.0000004500', '0.0000004500', '0.0000004500',
#        '0.0000004500', '0.0000004500', '0.0000004500', '0.0000004500',
#        '0.0000004500', '0.0000004500', '0.0000004500', '0.0000004500',
#        '0.0000004500', '0.0000004500', '0.0000004500', '0.0000004500',
# ...

# %%
mX0=3*m1step
m2=m1step + m1step*0.3

# %%
# Open the file in write mode
with open("database.txt", "w") as file:
    for i in range(300):
        file.write(str(mX0[i]) + " " + str(m1step[i]) + " " + str(m2[i]) + " " + str(mS0step[i]) + " " + str(gXstep[i]) + " " + str(epsilondarkstep[i]) + " " + str(lambdaphihstep[i]) + " " + str(Ychistep[i]) + "\n")

# %%
Omega_DM=0.120
epsilon_used=0.001
epsilon_used_squared=epsilon_used**2
epsilon_needed=[]

# %%
mass_zeta, mass1, mass2, massS0, massgX, massepsilondark, masslambdaphih, massYchi, Omega = np.loadtxt('data_out', delimiter=' ', unpack=True)

# %% [markdown]
# $$\Omega_0 : \frac{1}{\epsilon_0^2} = \Omega_{True} : \frac{1}{\epsilon_{True}^2}$$
# $$ \epsilon_{True}^2= \frac{\Omega_0}{\Omega_{True}} \epsilon_0^2 $$

# %%
for i in range(len(Omega)):
    epsilon_needed.append((Omega[i]/0.120)*epsilon_used_squared)
    #epsilon_needed.append((Omega_DM/Omega[i]))
    #epsilon_needed.append(np.sqrt((Omega_DM/Omega[i])*epsilon_dark_squared[i]))

# %%
epsilon_actually_needed=np.sqrt(epsilon_needed)

# %%
mass1
# Out:
# array([0.05, 0.06, 0.07, 0.08, 0.09, 0.1 , 0.11, 0.12, 0.13, 0.14, 0.15,
#        0.16, 0.17, 0.18, 0.19, 0.2 , 0.21, 0.22, 0.23, 0.24, 0.25, 0.26,
#        0.27, 0.28, 0.29, 0.3 , 0.31, 0.32, 0.33, 0.34, 0.35, 0.36, 0.37,
#        0.38, 0.39, 0.4 , 0.41, 0.42, 0.43, 0.44, 0.45, 0.46, 0.47, 0.48,
#        0.49, 0.5 , 0.51, 0.52, 0.53, 0.54, 0.55, 0.56, 0.57, 0.58, 0.59,
#        0.6 , 0.61, 0.62, 0.63, 0.64, 0.65, 0.66, 0.67, 0.68, 0.69, 0.7 ,
#        0.71, 0.72, 0.73, 0.74, 0.75, 0.76, 0.77, 0.78, 0.79, 0.8 , 0.81,
#        0.82, 0.83, 0.84, 0.85, 0.86, 0.87, 0.88, 0.89, 0.9 , 0.91, 0.92,
#        0.93, 0.94, 0.95, 0.96, 0.97, 0.98, 0.99, 1.  , 1.01, 1.02, 1.03,
#        1.04, 1.05, 1.06, 1.07, 1.08, 1.09, 1.1 , 1.11, 1.12, 1.13, 1.14,
#        1.15, 1.16, 1.17, 1.18, 1.19, 1.2 , 1.21, 1.22, 1.23, 1.24, 1.25,
#        1.26, 1.27, 1.28, 1.29, 1.3 , 1.31, 1.32, 1.33, 1.34, 1.35, 1.36,
#        1.37, 1.38, 1.39, 1.4 , 1.41, 1.42, 1.43, 1.44, 1.45, 1.46, 1.47,
# ...

# %%
epsilon_actually_needed
# Out:
# array([3.29393382e-04, 3.55281578e-04, 3.90704492e-04, 4.23851389e-04,
#        4.28407905e-04, 4.29699507e-04, 4.28680145e-04, 4.20029761e-04,
#        4.04835357e-04, 3.83470990e-04, 3.39950977e-04, 2.64701089e-04,
#        2.10178496e-04, 1.73060683e-04, 1.44885012e-04, 1.23760521e-04,
#        1.07819293e-04, 9.53065230e-05, 8.52447457e-05, 7.68114575e-05,
#        6.97017456e-05, 6.35085296e-05, 5.80947502e-05, 5.32290647e-05,
#        4.89046692e-05, 4.49073120e-05, 4.12310563e-05, 3.78593890e-05,
#        3.47610894e-05, 3.17542648e-05, 2.90114920e-05, 2.62995564e-05,
#        2.38047614e-05, 2.14087210e-05, 1.89296945e-05, 1.65831240e-05,
#        1.35400640e-05, 1.04083300e-05, 7.07106781e-06, 4.08248290e-06,
#        2.88675135e-06, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 2.88675135e-06, 5.77350269e-06,
#        7.07106781e-06, 8.66025404e-06, 1.04083300e-05, 1.19023807e-05,
# ...

# %%
plt.plot(mass1, epsilon_actually_needed, label='Relic density',color = "black")
plt.title(r'Thermal iDM,  $\delta= 0.3m_1$,  $m_{Z^i}=3m_1$,  $\alpha_D=0.39$,  $Y_\chi=0.005$,  $m_\phi=1$ GeV')
plt.xlabel('$m_1$ [GeV]')
plt.ylabel('$\epsilon_D$')
plt.xscale('log')
plt.yscale('log')
plt.legend()
plt.grid(which='major')
plt.grid(which='minor', axis='y',linestyle='--')
plt.show()

# %%
plt.plot(mass1, Omega, label='Relic density',color = "black")
plt.title(r'Thermal iDM,  $\delta= 0.3m_1$,  $m_{Z^i}=3m_1$,  $\alpha_D=0.39$,  $Y_\chi=0.005$,  $m_\phi=1$ GeV')
plt.xlabel('$m_1$ [GeV]')
plt.ylabel('$\epsilon_D$')
plt.xscale('log')
plt.yscale('log')
plt.legend()
plt.grid(which='major')
plt.grid(which='minor', axis='y',linestyle='--')
plt.show()
