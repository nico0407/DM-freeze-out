# %%
import matplotlib.pyplot as plt
import csv
import numpy as np

from scipy import integrate
from scipy import special

# %% [markdown]
# # UPDATE 05/01/2023
# # This is the standard just dark photon mediated complete file for $m_1=0.05$ GeV and $\delta=0.3 m_1$. WHITOUT THE DARK SCALAR INTERACTION, SO EXACLTY CORDAN COMPUTATION A PART FOR THE 2s staff..
# # Means: there are my factor 2s in the coannihilation cross section with the dark photon, and the 1/4 factors to unpolarize the cross section
# # NO hadron cross section, so no coannihilation cross section going to muons

# %%
X, G = np.loadtxt('dofdata/gstarSteigmanQCDFine.txt', delimiter=' ', unpack=True)

# %%
plt.plot(X, G, label='g_star Steigman QCD Fine',color = "black")
plt.title('g_star Steigman QCD Fine')
plt.xlabel('T [GeV]')
plt.ylabel('g_star')
plt.xscale('log')
plt.yscale('log')
plt.legend()
plt.grid(which='major')
plt.grid(which='minor', axis='y',linestyle='--')
plt.show()

# %% [markdown]
# ![g_star.png](attachment:g_star.png)

# %%
from scipy import optimize
import pandas as pd

# %%
d = {'T':X,'g_star':G}

# %%
df = pd.DataFrame(d)

# %%
df
# Out:
#                T      g_star
# 0       0.001031   10.391061
# 1       0.001144   10.391061
# 2       0.001277   10.391061
# 3       0.001392   10.446927
# 4       0.001516   10.446927
# ..           ...         ...
# 246  4109.770190  105.530726
# 247  4422.869883  105.530726
# 248  4818.426358  105.530726
# 249  5412.431122  105.530726
# 250  5718.832171  105.530726
#
# [251 rows x 2 columns]

# %%
data = np.loadtxt("dofdata/gstarSteigmanQCDFine.txt",delimiter = ' ')
#data = np.loadtxt("test4multiplot.txt", dtype = str)     #if file contains multiple data types
#data
temp = data[:,0]
gstar = data[:,1]
#plot data
plt.figure(figsize = [10,6])
plt.plot(temp,gstar,"o", color = "red", label = "Test data", markersize=4)
plt.title("g_star behaviour", fontsize=16)
plt.xlabel('T [GeV]', fontsize=14)
plt.ylabel('g_star', fontsize=14)
plt.legend()
plt.hlines(10.8,0.0001,100000,color='black', linestyle='dashed',linewidth=1)
plt.hlines(19,0.0001,100000,color='black', linestyle='dashed',linewidth=1)
plt.hlines(50,0.0001,100000,color='black', linestyle='dashed',linewidth=1)
plt.hlines(84,0.0001,100000,color='black', linestyle='dashed',linewidth=1)
plt.hlines(103,0.0001,100000,color='black', linestyle='dashed',linewidth=1)
plt.hlines(105.5,0.0001,100000,color='black', linestyle='dashed',linewidth=1)
plt.vlines(0.017,0,120,color='black', linestyle='dashed',linewidth=1)
plt.vlines(0.12,0,120,color='black', linestyle='dashed',linewidth=1)
plt.vlines(0.23,0,120,color='black', linestyle='dashed',linewidth=1)
plt.vlines(9.38,0,120,color='black', linestyle='dashed',linewidth=1)
plt.vlines(100,0,120,color='black', linestyle='dashed',linewidth=1)
plt.vlines(5718,0,120,color='black', linestyle='dashed',linewidth=1)
plt.ylim(9,120)
plt.xlim(5*1E-4,20000)
plt.xscale('log')
plt.yscale('log')
plt.grid(True)                                 # comment this if u do not need grid
plt.show()

# %%
temp1 = data[0:32,0]
#print(x1)
temp2 = data[32:56,0]
#print(x2)
temp3 = data[56:100,0]
#print(x3)
temp4 = data[100:168,0]
#print(x3)
temp6 = data[168:217,0]
#print(x4)
temp5 = data[217:250,0]
#print(x5)

gstar1 = data[0:32,1]
#print(x1)
gstar2 = data[32:56,1]
#print(x2)
gstar3 = data[56:100,1]
#print(x3)
gstar4 = data[100:168,1]
#print(x3)
gstar6 = data[168:217,1]
#print(x4)
gstar5 = data[217:250,1]
#print(x5)

# %%
print(temp1)
print(temp2)
print(temp3)
print(temp4)
print(temp6)
print(temp5)
# Out:
# [0.00103107 0.00114409 0.00127729 0.00139152 0.00151597 0.00171331
#  0.00191278 0.00210951 0.00235511 0.0026293  0.00295344 0.00337899
#  0.00377239 0.00405979 0.0045048  0.00487775 0.00518551 0.00558057
#  0.00589649 0.00654284 0.00726004 0.00776548 0.00840838 0.0091045
#  0.00973835 0.01022688 0.01080583 0.01170043 0.01282508 0.01388686
#  0.01540908 0.01668479]
# [0.01874165 0.0205431  0.02265591 0.02483361 0.02688956 0.02929441
#  0.03171967 0.03476857 0.03787808 0.04177375 0.04578906 0.05049836
#  0.05501464 0.06030268 0.06569581 0.07157127 0.07749658 0.08289187
#  0.08920693 0.09600309 0.10143788 0.10587678 0.11187053 0.11748257]
# [0.12337614 0.12877504 0.13359033 0.13774033 0.14201925 0.14553789
#  0.14823397 0.15377688 0.15662559 0.16050612 0.16448279 0.16959247
#  0.17063329 0.17168051 0.17379426 0.17486088 0.17593404 0.17810016
#  0.18029295 0.18139945 0.18363286 0.18475986 0.18475986 0.18818252
#  0.19049944 0.19402843 0.19641733 0.19883565 0.19883565 0.20251906
# ...

# %%
print(gstar1)
print(gstar2)
print(gstar3)
print(gstar4)
print(gstar6)
print(gstar5)
# Out:
# [10.39106145 10.39106145 10.39106145 10.44692737 10.44692737 10.44692737
#  10.44692737 10.44692737 10.44692737 10.5027933  10.5027933  10.5027933
#  10.55865922 10.55865922 10.55865922 10.61452514 10.61452514 10.61452514
#  10.61452514 10.61452514 10.67039106 10.61452514 10.61452514 10.61452514
#  10.61452514 10.61452514 10.61452514 10.61452514 10.67039106 10.67039106
#  10.67039106 10.72625698]
# [11.00558659 11.2849162  11.56424581 11.84357542 12.12290503 12.34636872
#  12.68156425 13.12849162 13.46368715 13.79888268 14.18994413 14.63687151
#  14.91620112 15.30726257 15.58659218 15.92178771 16.31284916 16.53631285
#  16.70391061 17.15083799 17.48603352 17.98882682 18.43575419 18.93854749]
# [19.32960894 20.         20.55865922 21.11731844 22.06703911 22.84916201
#  23.57541899 24.41340782 25.1396648  25.81005587 26.59217877 27.26256983
#  27.82122905 28.37988827 28.88268156 29.44134078 30.16759777 30.78212291
# ...

# %%
temp[32]
# Out:
# 0.01874164876284413

# %%
temp[56]
# Out:
# 0.1233761398411089

# %%
temp[100]
# Out:
# 0.23169929488609683

# %%
temp[168]
# Out:
# 9.387329727864389

# %%
temp[217]
# Out:
# 178.10015797967904

# %%
temp[250]
# Out:
# 5718.8321713429

# %%
def lin1(t,a1,a2,a3):
    return a1+a2*t+ a3*t**2

# %%
popt1,pcov1 = optimize.curve_fit(lin1,temp1,gstar1,p0=(0,0,0))

# %%
popt1
# Out:
# array([   10.37860368,    44.41674668, -1656.4724049 ])

# %%
def g_star1(t): 
    return lin1(t,a1=popt1[0],a2=popt1[1],a3=popt1[2])

# %%
#t=np.logspace(np.log10(1E-3),np.log10(1E-1))
t1=np.linspace(0.00103107,0.01668479, 1000)
plt.semilogx(temp1,gstar1,'ro', markersize=4) #semilogx Make a plot with log scaling on the x axis.
plt.plot(t1,g_star1(t1),color = "black" )   #BUT THAT WASN'T THE PHASE SPACE FUNCTION? SO THIS PLOT ISN'T REFERRING TO THAT? NO, IS G STAR SQUARED BUT HOW?!
plt.xlabel('$T$ [GeV]',size=15)
plt.ylabel(r'$g_*$',size=15)

plt.title('parametrization of the $g_*$', size= 15)
#plt.legend()
plt.grid()

# %%
def lin2(t,a4,a5,a6):
    return a4+a5*t+ a6*t**2

# %%
popt2,pcov2 = optimize.curve_fit(lin2,temp2,gstar2,p0=(0,0,0))

# %%
popt2
# Out:
# array([   9.10908676,  122.61245237, -366.57202888])

# %%
def g_star2(t):
    return lin2(t,a4=popt2[0],a5=popt2[1],a6=popt2[2])

# %%
#t=np.logspace(np.log10(1E-3),np.log10(1E-1))
t2=np.linspace(0.01874165,0.11748257, 1000)
plt.semilogx(temp2,gstar2,'ro', markersize=4) #semilogx Make a plot with log scaling on the x axis.
plt.plot(t2,g_star2(t2),color = "black" )   #BUT THAT WASN'T THE PHASE SPACE FUNCTION? SO THIS PLOT ISN'T REFERRING TO THAT? NO, IS G STAR SQUARED BUT HOW?!
plt.xlabel('$T$ [GeV]',size=15)
plt.ylabel(r'$g_*$',size=15)

plt.title('parametrization of the $g_*$', size= 15)
#plt.legend()
plt.grid()

# %%
def lin3(t,a7,a8,a9):
    return a7+a8*t+ a9*t**2

# %%
popt3,pcov3 = optimize.curve_fit(lin3,temp3,gstar3,p0=(0,0,0))

# %%
popt3
# Out:
# array([  24.23107196, -219.74347911, 1439.42995816])

# %%
def g_star3(t):
    return lin3(t,a7=popt3[0],a8=popt3[1],a9=popt3[2])

# %%
#t=np.logspace(np.log10(1E-3),np.log10(1E-1))
t3=np.linspace(0.12337614,0.22748515, 1000)
plt.semilogx(temp3,gstar3,'ro', markersize=4) #semilogx Make a plot with log scaling on the x axis.
plt.plot(t3,g_star3(t3),color = "black" )   #BUT THAT WASN'T THE PHASE SPACE FUNCTION? SO THIS PLOT ISN'T REFERRING TO THAT? NO, IS G STAR SQUARED BUT HOW?!
plt.xlabel('$T$ [GeV]',size=15)
plt.ylabel(r'$g_*$',size=15)

plt.title('parametrization of the $g_*$', size= 15)
#plt.legend()
plt.grid()

# %%
def lin4(t,a10,a11,a12):
    return a10/(1+np.exp(-a11*(t-a12)))#a10+a11*t+ a12*t**2 +a18*t**3

# %%
popt4,pcov4 = optimize.curve_fit(lin4,temp4,gstar4,p0=(0,0,0))

# %%
popt4
# Out:
# array([8.30283616e+01, 2.80379505e+00, 7.12609355e-02])

# %%
def g_star4(t):
    return lin4(t,a10=popt4[0],a11=popt4[1],a12=popt4[2])

# %%
#t=np.logspace(np.log10(1E-3),np.log10(1E-1))
t4=np.linspace(0.23169929,8.61670073, 1000)
plt.semilogx(temp4,gstar4,'ro', markersize=4) #semilogx Make a plot with log scaling on the x axis.
plt.plot(t4,g_star4(t4),color = "black" )   #BUT THAT WASN'T THE PHASE SPACE FUNCTION? SO THIS PLOT ISN'T REFERRING TO THAT? NO, IS G STAR SQUARED BUT HOW?!
plt.xlabel('$T$ [GeV]',size=15)
plt.ylabel(r'$g_*$',size=15)

plt.title('parametrization of the $g_*$', size= 15)
#plt.legend()
plt.grid()

# %%
def lin6(t,a15,a16,a17):
    return a15+a16*t+ a17*t**2

# %%
popt6,pcov6 = optimize.curve_fit(lin6,temp6,gstar6,p0=(0,0,0))

# %%
popt6
# Out:
# array([ 8.04239785e+01,  3.75753023e-01, -1.43230640e-03])

# %%
def g_star6(t):
    return lin6(t,a15=popt6[0],a16=popt6[1],a17=popt6[2])

# %%
#t=np.logspace(np.log10(1E-3),np.log10(1E-1))
t6=np.linspace(9.38732973,162.4822869, 1000)
plt.semilogx(temp6,gstar6,'ro', markersize=4) #semilogx Make a plot with log scaling on the x axis.
plt.plot(t6,g_star6(t6),color = "black" )   #BUT THAT WASN'T THE PHASE SPACE FUNCTION? SO THIS PLOT ISN'T REFERRING TO THAT? NO, IS G STAR SQUARED BUT HOW?!
plt.xlabel('$T$ [GeV]',size=15)
plt.ylabel(r'$g_*$',size=15)

plt.title('parametrization of the $g_*$', size= 15)
#plt.legend()
plt.grid()

# %%
def lin5(t,a13,a14):
    return a13+a14*t#+ a15*t**2

# %%
popt5,pcov5 = optimize.curve_fit(lin5,temp5,gstar5,p0=(0,0))

# %%
popt5
# Out:
# array([1.05470885e+02, 9.82116227e-06])

# %%
def g_star5(t):
    return lin5(t,a13=popt5[0],a14=popt5[1])#,a15=popt5[2])

# %%
#t=np.logspace(np.log10(1E-3),np.log10(1E-1))
t5=np.linspace(178.10015798,5412.43112233, 1000)
plt.semilogx(temp5,gstar5,'ro', markersize=4) #semilogx Make a plot with log scaling on the x axis.
plt.plot(t5,g_star5(t5),color = "black" )   #BUT THAT WASN'T THE PHASE SPACE FUNCTION? SO THIS PLOT ISN'T REFERRING TO THAT? NO, IS G STAR SQUARED BUT HOW?!
plt.xlabel('$T$ [GeV]',size=15)
plt.ylabel(r'$g_*$',size=15)

plt.title('parametrization of the $g_*$', size= 15)
#plt.legend()
plt.grid()

# %%
plt.semilogx(temp1,gstar1,'ro', markersize=2)
plt.semilogx(temp2,gstar2,'ro', markersize=2)
plt.semilogx(temp3,gstar3,'ro', markersize=2)
plt.semilogx(temp4,gstar4,'ro', markersize=2)
plt.semilogx(temp6,gstar6,'ro', markersize=2)
plt.semilogx(temp5,gstar5,'ro', markersize=2)
plt.plot(t1,g_star1(t1),color = "black" )
plt.plot(t2,g_star2(t2),color = "black" )
plt.plot(t3,g_star3(t3),color = "black" )
plt.plot(t4,g_star4(t4),color = "black" )
plt.plot(t6,g_star6(t6),color = "black" )
plt.plot(t5,g_star5(t5),color = "black" )
plt.xlabel('$T$ [GeV]',size=15)
plt.ylabel(r'$g_*^{1/2}$',size=15)
plt.yscale('log')

plt.axvline(0.00108)
plt.axvline(0.065)


plt.title('parametrization of the $g_*$', size= 15)

plt.grid(which='major')
plt.grid(which='minor', axis='y',linestyle='--')

# %% [markdown]
# # 21/12/2022 THIS IS THE CORE FILE
# ## What I have done:
# ## There are other four notebook that are "Coannihilation", "Scattering", "Decay" and "Scalar-coannihilation". The first one is the most important. There I have made some assumptions. I choose a range of x, from that range I have computed the range of temperatures (T), and from that I have computed a range of energies of the centre of mass where the coannihilation process mediated by the dark photon can occur. Then I have plotted the scross section and that seemed to be constant, so I have picked a value for it that could work as a $\sigma_0$ in the computation of $x_f$ taken from Kolb-Turner. In that way I got the freeze out temperatures for the two spieces. I have used just the coannihilation cross section for computed the freeze out temperatures, and then used those values for all the other notebooks. After having done that, I have performed the thermal average cross section times velocity computation separately in each notebook and I got a result for them to plug into my Boltzmann differential equation. After integrating it and got the plot I have computed the relic abundance for the Benchmark choosen.
# # ALL OF IT IS WRONG.
# ## The Kolb-Turner formula do not apply to our case of iDM. So I have insert all the formula for the thermal average cross section times velocity ($\langle \sigma v \rangle$) including the integral in $ds$ (that depend on the temperature) in my Boltzmann differential equation and it works. It plot and solve the coupled differential equations(in 40 min).In this way I do not have to make any kind of assumption on the energy range or on the cross section, it's pretty formal. For the moment are inside just the coannihilation and the scattering, I am still giving a sharp value for the decay.
# # What I need to do more:
# ## Modify the cross section given into the integral and make them unpolarized (sum over the possible final states and average on the initial ones).
# ## Ending up the analytical form of the decay cross section.
# ## Plug inside the scalar coannihilation cross section. What values do I need to insert in the cross section for the parameters? ($\Delta_\phi$, $Y^\chi$....)
# ## Modify again the Boltzmann equation for adding tha scalar coannihilation term. The scalar interaction is diagonal, while the vector interaction is off-diagonal, so it consist in the addition of a totally new term in the differential equation.
# ## Check all the little parameter values (i.e. $g_*$...)
# ## Check if the differential equation is correct (python is not so easy for that kind of stuff). And I am using in the integration a variable "t" that probably is x1, but then I plot in x2, is it still correct?

# %%
from scipy import integrate

# %%
m1 = 0.050                                #GeV DM Mass
delta=0.3*m1
m2=m1+delta

mzprime=3*m1                                  #Mass of the dark photon in GeV    150 MeV
Mp = 1.22e19   
m=0.000501                                 # I choose the electron mass in Gev
mf=0.000501 
mmu=0.1057                                 # mass of the muon in GeV


s0= m1**2 + m2**2 + 2*m1*m2
s0_SCAT= m1**2 + mf**2 + 2*m1*mf


epsilon=1E-3               # Has inside some factors as indicated in the computation papers     1E-4
alpha_dark=1E-1               # what values?       (1E-3    -   1E-1)  
alpha_em=1/137

# %%
def pfin_pinit(s):
    return np.sqrt(abs(((s-2*m**2)**2)-4*(m**4))/abs(((s-(m1**2)-(m2**2))**2)-4*(m1**2)*(m2**2)))

def p_fin(s):
    return np.sqrt((((s-2*m**2)**2)-4*(m**4))/4*s)

def p_init(s):
    return np.sqrt(abs((((s-(m1**2)-(m2**2))**2)-4*(m1**2)*(m2**2))/4*s))

def E1(s):
    return np.sqrt(m1**2 + p_init(s)**2)

def E2(s):
    return np.sqrt(m2**2 + p_init(s)**2)

# %%
def pfin_pinit_mu(s):
    return np.sqrt(abs(((s-2*mmu**2)**2)-4*(mmu**4))/abs(((s-(m1**2)-(m2**2))**2)-4*(m1**2)*(m2**2)))

def p_fin_mu(s):
    return np.sqrt(abs((((s-2*mmu**2)**2)-4*(mmu**4))/4*s))

def p_init_mu(s):
    return np.sqrt(abs((((s-(m1**2)-(m2**2))**2)-4*(m1**2)*(m2**2))/4*s))

def E1_mu(s):
    return np.sqrt(m1**2 + p_init_mu(s)**2)

def E2_mu(s):
    return np.sqrt(m2**2 + p_init_mu(s)**2)

# %%
def pfin_pinit_SCAT(s):
    return (np.sqrt(abs(((s-m2**2-mf**2)**2)-4*(mf**2)*(m2**2))/abs(((s-(m1**2)-(mf**2))**2)-4*(mf**2)*(m1**2))))

def p_fin_SCAT(s):
    return np.sqrt(abs((((s-m2**2-mf**2)**2)-4*(mf**2)*(m2**2))/4*s))

def p_init_SCAT(s):
    return np.sqrt(abs((((s-(m1**2)-(mf**2))**2)-4*(mf**2)*(m1**2))/4*s))

def E1_SCAT(s):
    return np.sqrt(m1**2 + p_init_SCAT(s)**2)

def E2_SCAT(s):
    return np.sqrt(mf**2 + p_init_SCAT(s)**2)

def E3_SCAT(s):
    return np.sqrt(m2**2 + p_fin_SCAT(s)**2)

def E4_SCAT(s):
    return np.sqrt(mf**2 + p_fin_SCAT(s)**2)

def a_SCAT(s):
    return m1**2+m2**2-2*E1_SCAT(s)*E2_SCAT(s)-mzprime**2

# %%
Tfo2=0.002831671668678899
# THIS IS JUST TO TEST THET THE SIGMA ARE WRITTEN WELL AND THAT I GET THE SAME RESULT
# THAT I GET IN THE OTHER NOTEBOOKS

# %%
def sigma(s_tilda):
    return (2/4)*((8*np.pi*(epsilon**2)*alpha_dark*alpha_em)/(((s_tilda)-mzprime**2)**2))*(pfin_pinit(s_tilda)/(s_tilda))*(((s_tilda)*E1(s_tilda)*E2(s_tilda)/2)+(2*(p_init(s_tilda)**2)*(p_fin(s_tilda)**2)/3)+((m**2)*((s_tilda)-(m1**2)-(m2**2))/2)+((m1*m2)*((s_tilda)-2*(m**2))/2)+2*((m**2)*m1*m2))        


# This is gordan's cross section:
# ((8*np.pi*(epsilon**2)*alpha_dark*alpha_em)/(((s_tilda)-mzprime**2)**2))*(pfin_pinit(s_tilda)/(s_tilda))*(((s_tilda)*E1(s_tilda)*E2(s_tilda)/2)+(2*(p_init(s_tilda)**2)*(p_fin(s_tilda)**2)/3)+((m**2)*((s_tilda)-(m1**2)-(m2**2))/2)+((m1*m2)*((s_tilda)-2*(m**2))/2)+((m**2)*m1*m2))
# Mine has a 16 multiplying, instead of 8 and a 2 factor in the latest quantity.

# %%
def sigma_SCAT(s):
    return (1/4)*((16*np.pi*(epsilon**2)*alpha_dark*alpha_em)/s)*(pfin_pinit_SCAT(s))*(  4*np.pi*(E1_SCAT(s)*E2_SCAT(s)*E3_SCAT(s)*E4_SCAT(s) -(a_SCAT(s)/2)*(E1_SCAT(s)*E4_SCAT(s)+E2_SCAT(s)*E3_SCAT(s))+(a_SCAT(s)**2)/4+ (s-(m1**2)-(mf**2))*(s-(m1**2)-(mf**2))/4 -(mf**2)*E1_SCAT(s)*E3_SCAT(s)-(m1*m2)*E2_SCAT(s)*E4_SCAT(s) -(a_SCAT(s)/2)*(mf**2 + m1*m2)+ 2*m1*m2*mf*mf  )*(2/(a_SCAT(s)**2-4*p_init_SCAT(s)*p_init_SCAT(s)*p_fin_SCAT(s)*p_fin_SCAT(s))) + (4*np.pi/2*p_init_SCAT(s)*p_fin_SCAT(s))*((E1_SCAT(s)*E4_SCAT(s)+E2_SCAT(s)*E3_SCAT(s))/2 -(a_SCAT(s)/2)+ (mf**2)/2 +(m1*m2)/2  )*np.log((a_SCAT(s)+2*p_init_SCAT(s)*p_fin_SCAT(s))/(a_SCAT(s)+2*p_init_SCAT(s)*p_fin_SCAT(s))) +2*np.pi     )

# %%
NUMERATOR=(integrate.quad(lambda s_tilda: sigma_SCAT(s_tilda)* (s_tilda-s0_SCAT)* np.sqrt(s_tilda)* special.kv(1,np.sqrt(s_tilda)/Tfo2), s0_SCAT, np.inf )[0])    

NUMERATOR
# Out:
# 4.3106857541449335e-23

# %%
DENOMINATOR= ( 1/(8* m1**2 * mf**2  *Tfo2 *(special.kn(2,m1/Tfo2)*(special.kn(2,mf/Tfo2)))))

DENOMINATOR
# Out:
# 1.563993475866895e+17

# %% [markdown]
# # Define some parameters

# %%
# parameters
m1 = 0.050                                #GeV DM Mass
delta=0.3*m1
m2=m1+delta
Mp = 1.22e19                            #GeV Planck Mass

# %% [markdown]
# $x1=m1/T$. In our case $m_2$ will be $m_1+\delta$.
#
# We can extract that $T=m_1/x_1$. So $x_2=m_2/T$ will be $x_2=\frac{m_2}{m_1}x_1$

# %%
x1=np.logspace(np.log10(1),np.log10(100),1000)
x2=x1*((m1+delta)/m1)
plt.plot(x1,x2)

# %% [markdown]
# $$\frac{dY}{dx}=- \Bigl(\frac{45}{\pi M_P^2}\Bigr)^{-1/2} \frac{g_*^{1/2}m}{x^2} \langle\sigma v\rangle(Y^2-Y_{eq}^2)$$

# %% [markdown]
# $$ Y_{eq}(x)= \frac{45}{2 \pi^4} \frac{g_{\chi}}{g_{*s}}x^{3/2}e^{-x}= 0.145 \frac{g_{\chi}}{g_{*s}}x^{3/2}e^{-x} $$

# %%
# add g_{chi}/g_* term at the Y_eq!!!!!

# %% [markdown]
# $$\Omega h^2 \approx \frac{3 \times 10^{-27}cm^3/s}{\langle \sigma_{ann}v \rangle}  \approx 0.12 \ \ \ \ \ \ (\text{Plank result})$$

# %% [markdown]
# $$1 \text{cm}= 5.068 \times 10^{13} \hbar c \cdot \text{GeV}^{-1}
#     \ \ \ \ \ \ \ \ \
#     1s= 1.519 \times 10^{24} \hbar \cdot \text{GeV}^{-1}
#     \ \ \ \ \ \ \ \ \
#     0.1 \text{pb} \approx 2.6 \times 10^{-10} \hbar c \cdot \text{GeV}^{-2}$$

# %% [markdown]
# $$\langle \sigma v \rangle = 3 \times 10^{-26} \frac{(5.068 \times 10^{13} \hbar c \cdot \text{GeV}^{-1})^3}{1.519 \times 10^{24} \hbar \cdot \text{GeV}^{-1}}= 2.6 \times 10^{-9} (\hbar c)^2 \text{Gev}^{-2} c$$

# %% [markdown]
# $$\Omega_{\chi}h^2= \frac{\rho_{\chi}^0h^2}{\rho_c^0}= \frac{m_{\chi}s_0 Y_0 h^2}{\rho_c^0} \ \ \ \ \ \ \ \ \ \  s_0= \frac{2 \pi^2}{45}g_{*s}(T_{\gamma}) T_{\gamma}^3$$

# %% [markdown]
# $$\frac{s_0 h^2}{\rho_c^0}= \frac{3120 \times 0.71^2}{1.05375 \times 10^{-5}} \approx 1.5 \times 10^{8}$$

# %% [markdown]
# $$\Omega_{\chi}h^2= 1.5 \times 10^{8} m_\chi Y_0 (c^2/ \text{GeV})= 1.5 \times 10^{10} Y_0 \Big( \frac{m_\chi}{100 \text{GeV}/c^2} \Big)\rightarrow = 0.118$$

# %% [markdown]
# $$ Y_0= 7.9 \times 10^{-12}\Big( \frac{100 \text{GeV}/c^2}{m_\chi} \Big)$$

# %% [markdown]
# # Define the equilibrium distribution for $Y_1$ and $Y_2$

# %%
def Yequilibrium(x,p):
    #T=m/x  
    # P sarebbe m
    yota = np.empty_like(x)
    
    point1 = (p/x <= 0.01668479)
    point2 = (0.01668479 < p/x) & (p/x <= 0.11748257)
    point3 = (0.11748257 < p/x) & (p/x <= 0.22748515)
    point4 = (0.22748515 < p/x) & (p/x <= 8.6167)
    point6 = (8.6167 < p/x) & (p/x <= 162.48)
    point5 = (162.48 < p/x)
    
    yota[point1] = 0.145*x[point1]**(3/2)*np.exp(-x[point1])*2/g_star1(p/x[point1])
    yota[point2] = 0.145*x[point2]**(3/2)*np.exp(-x[point2])*2/g_star2(p/x[point2])
    yota[point3] = 0.145*x[point3]**(3/2)*np.exp(-x[point3])*2/g_star3(p/x[point3])
    yota[point4] = 0.145*x[point4]**(3/2)*np.exp(-x[point4])*2/g_star4(p/x[point4])
    yota[point6] = 0.145*x[point6]**(3/2)*np.exp(-x[point6])*2/g_star6(p/x[point6])
    yota[point5] = 0.145*x[point5]**(3/2)*np.exp(-x[point5])*2/g_star5(p/x[point5])
    return yota

# THIS ONE CAN BE PLOTTED BUTH NOE USED FOR INTEGRATION

# %%
plt.plot(x2, Yequilibrium(x1,m1),'b',label=r'$Y_{\rm eq1}$(with g_* and m=0.05 GeV)')
plt.plot(x2, Yequilibrium(x2,m2),'k',label=r'$Y_{\rm eq2}$(with g_* and m=0.05 GeV)')


plt.yscale('log')
#plt.ylim(1E-14,1)
plt.ylim(1E-14,1E-1)
#plt.xlim(1,1000)
plt.xlim(1,60)
plt.xlabel('$x_2 = m_2/T$', size= 15)
plt.ylabel('$Y$', size= 15)
plt.title('$m = 0.05$ GeV', size= 15)
plt.legend()
plt.grid()
plt.show()


# THIS EQUILIBRIUM FUNCTIONS ARE GOOD. 
#         LITTERALLY EXACTLY AS GORDON'S PAPER!!!!!!
# THERE IS EVERITHING INSIDE, ALSO THE g_* value. 
# THEY ARE GOOD.

# %%
def Yequil(xx,p):
    T=p/xx
    if 0 < T<= 0.01668479:
        return 0.145*xx**(3/2)*np.exp(-xx)*2/g_star1(T)   #missing piece of the formula.
    elif 0.01668479<T<=0.11748257:
        return 0.145*xx**(3/2)*np.exp(-xx)*2/g_star2(T)
    elif 0.11748257<T<=0.22748515:
        return 0.145*xx**(3/2)*np.exp(-xx)*2/g_star3(T)
    elif 0.22748515<T<=8.6167:
        return 0.145*xx**(3/2)*np.exp(-xx)*2/g_star4(T)
    elif 8.6167<T<=162.48:
        return 0.145*xx**(3/2)*np.exp(-xx)*2/g_star6(T)
    else:
        return 0.145*xx**(3/2)*np.exp(-xx)*2/g_star5(T)
    
    
# IF I USE THIS ONE INSTEAD OF Yeq I GOT THE FOLLOWING ERROR:
# The truth value of an array with more than one element is ambiguous. Use a.any() or a.all() !!!!! 
# HOW TO PUNT THE g_* INSIDE OF THE EQUILIBRIUM DISTRIBUTION?!?!?!?

# SAME FOR Yequilibrium. Y is a piecewise define function, what I have to do?!?!?

# %%
g_star1(0.00216)
# Out:
# 10.466815411530508

# %%
0.145*30**(3/2)*np.exp(-30)*4/g_star1(0.00216)
# Out:
# 8.520417061609589e-13

# %%
def Yeq(x):
    return 0.145*x**(3/2)*np.exp(-x)

# %% [markdown]
# # Define some useful functions

# %%
quantity=np.sqrt(np.pi*(Mp**2)/45)*m2
quantity
# Out:
# 2.095279031334378e+17

# %%
def BEx(x,p):
    T=p/x
    if T< 0.01668479:                        #this value is wrong, you should place the last element of the first group
        return k*np.sqrt(g_star1(T))/x**2   #missing piece of the formula.
    elif 0.01668479<T<0.11748257:
        return k*np.sqrt(g_star2(T))/x**2
    elif 0.11748257<T<0.22748515:
        return k*np.sqrt(g_star3(T))/x**2
    elif 0.22748515<T<8.6167:
        return k*np.sqrt(g_star4(T))/x**2
    elif 8.6167<T<162.48:
        return k*np.sqrt(g_star6(T))/x**2
    else:
        return k*np.sqrt(g_star5(T))/x**2
    

# THIS ONE CAN BE USED FOR INTEGRATION BUT CANNOT BE PLOTTED

# %%
def BE(x,Y,p):
    return -(Y**2-Yequil(x)**2)*BEx(x,p)   #putting together the things to have the right formula

#THESE FUNCTIONS HAVE BEEN CREATED TO ACHIVE THE COMPLETE FORMULA FOR THE dY/dx

# %%
x=np.logspace(np.log10(1),np.log10(100),1000)

# %% [markdown]
# # Implement the iDM freeze-out

# %% [markdown]
# $$ \frac{dY_{1,2}}{dx} = - \frac{\lambda_A}{x^2} \Big[ Y_1 Y_2 - Y_1^{(0)}Y_2^{(0)} \Big] \pm x \lambda_D \Big( Y_2- \frac{Y_2^{(0)}}{Y_1^{(0)}}Y_1 \Big) \pm \frac{\lambda_S}{x^2}Y_f^{(0)} \Big( Y_2- \frac{Y_2^{(0)}}{Y_1^{(0)}}Y_1 \Big) $$

# %% [markdown]
# # I am going to insert the integral inside the differential equation....
# # Let's start with just the  cohannilation
#
# # It work!! it's like 40 min of integration but the calculation converge, and there is no need to use the kolb tarner formula for freeze out, it's just as it should be!!
#
# # Need to do the same for scattering and decay....

# %%
def odesiDM(t,z):
    t2=t*(m2/m1)

    
    Y1, Y2=z
    #assigng each ODE to a vector element
    #Y1=x[0]
    #Y2=x[1]
    
    #nell'equazione di sopra integro dY in dx, dove probebilmente nel paper di gordon è stato scelto
    #essere x2, quindi integro in x2 che sarebbe t2 nell'equazione di python in questo caso.
    
    #define each ODE
    
    
    #dY1dt= -k*m1*(Y1*Y2-Yequil(t,m1)*Yequil(t2,m2))/t2**2 + ks*m1*Yequil(t,m1)*(Y2-(Yequil(t2,m2)/Yequil(t,m1))*Y1)/t2**2 + t2*kd*m1*(Y2-(Yequil(t2,m2)/Yequil(t,m1))*Y1)
    #dY2dt= -k*m2*(Y1*Y2-Yequil(t,m1)*Yequil(t2,m2))/t2**2 - ks*m2*Yequil(t2,m2)*(Y2-(Yequil(t2,m2)/Yequil(t,m1))*Y1)/t2**2 - t2*kd*m2*(Y2-(Yequil(t2,m2)/Yequil(t,m1))*Y1)
    
    return [-(quantity*(integrate.quad(lambda s_tilda: sigma(s_tilda)* (s_tilda-s0)* np.sqrt(s_tilda)* special.kv(1,np.sqrt(s_tilda)/(m1/t)), s0, np.inf )[0])*( 1/(8* m1**2 * m2**2  *(m1/t) *(special.kn(2,m1/(m1/t))*(special.kn(2,m2/(m1/t)))))) )*(Y1*Y2-Yequil(t,m1)*Yequil(t2,m2))/t**2 + ((quantity*(integrate.quad(lambda s_tilda: sigma_SCAT(s_tilda)* (s_tilda-s0_SCAT)* np.sqrt(s_tilda)* special.kv(1,np.sqrt(s_tilda)/(m1/t)), s0_SCAT, np.inf )[0])*( 1/(8* m1**2 * mf**2  *(m1/t) *(special.kn(2,m1/(m1/t))*(special.kn(2,mf/(m1/t)))))) ))  *Yequil(t,m1)*(Y2-(Yequil(t2,m2)/Yequil(t,m1))*Y1)/t**2 + t*kd*(Y2-(Yequil(t2,m2)/Yequil(t,m1))*Y1),    -(quantity*(integrate.quad(lambda s_tilda: sigma(s_tilda)* (s_tilda-s0)* np.sqrt(s_tilda)* special.kv(1,np.sqrt(s_tilda)/(m1/t)), s0, np.inf )[0])*( 1/(8* m1**2 * m2**2  *(m1/t) *(special.kn(2,m1/(m1/t))*(special.kn(2,m2/(m1/t)))))) )*(Y1*Y2-Yequil(t,m1)*Yequil(t2,m2))/t**2 -  (quantity*(integrate.quad(lambda s_tilda: sigma_SCAT(s_tilda)* (s_tilda-s0_SCAT)* np.sqrt(s_tilda)* special.kv(1,np.sqrt(s_tilda)/(m1/t)), s0_SCAT, np.inf )[0])*( 1/(8* m1**2 * mf**2  *(m1/t) *(special.kn(2,m1/(m1/t))*(special.kn(2,mf/(m1/t)))))) )  *Yequil(t2,m2)*(Y2-(Yequil(t2,m2)/Yequil(t,m1))*Y1)/t**2 - t*kd*(Y2-(Yequil(t2,m2)/Yequil(t,m1))*Y1)]       


# I HAVE INSERT THE WHOLE INTEGRAL FOR GETTING THE COANNIHILATION CROSS SECTION INSIDE THE FORMULA
# WHITHOUT FIXING ANY TEMPERATURE OF FREEZEOUT VALUE FOR ANYONE AND IS WORKING VERY GOOD AS FOLLOWS:
# [-(quantity*(integrate.quad(lambda s_tilda: sigma(s_tilda)* (s_tilda-s0)* np.sqrt(s_tilda)* special.kv(1,np.sqrt(s_tilda)/(m1/t)), s0, np.inf )[0])*( 1/(8* m1**2 * m2**2  *(m1/t) *(special.kn(2,m1/(m1/t))*(special.kn(2,m2/(m1/t)))))) )*m1*(Y1*Y2-Yequil(t,m1)*Yequil(t2,m2))/t**2 + ks*m1*Yequil(t,m1)*(Y2-(Yequil(t2,m2)/Yequil(t,m1))*Y1)/t**2 + t*kd*m1*(Y2-(Yequil(t2,m2)/Yequil(t,m1))*Y1),    -(quantity*(integrate.quad(lambda s_tilda: sigma(s_tilda)* (s_tilda-s0)* np.sqrt(s_tilda)* special.kv(1,np.sqrt(s_tilda)/(m1/t)), s0, np.inf )[0])*( 1/(8* m1**2 * m2**2  *(m1/t) *(special.kn(2,m1/(m1/t))*(special.kn(2,m2/(m1/t)))))) )*m2*(Y1*Y2-Yequil(t,m1)*Yequil(t2,m2))/t**2 - ks*m2*Yequil(t2,m2)*(Y2-(Yequil(t2,m2)/Yequil(t,m1))*Y1)/t**2 - t*kd*m2*(Y2-(Yequil(t2,m2)/Yequil(t,m1))*Y1)]
# USING THE FOLLOWING CROSS SECTION FOR SCATTERING AND DECAY
# ks=fk(sigmav=2.696753758398017e-05) 
# kd=fk(sigmav=2.7897359041010654e-17)


# due to the fact that the scattering cross section approximation depends on T^2 I have 
# inserted that dependence in the differential equation. 
# lambda=ks*mi*T**2 and all is divided for x**2, so T**2/x**2= mi**2/x**4!!!!
# [-k*m1*(Y1*Y2-Yequil(t,m1)*Yequil(t2,m2))/t**2 + ks*m1*Yequil(t,m1)*(Y2-(Yequil(t2,m2)/Yequil(t,m1))*Y1)*(m1/t**4) + t*kd*m1*(Y2-(Yequil(t2,m2)/Yequil(t,m1))*Y1), -k*m2*(Y1*Y2-Yequil(t,m1)*Yequil(t2,m2))/t**2 - ks*m2*Yequil(t2,m2)*(Y2-(Yequil(t2,m2)/Yequil(t,m1))*Y1)*(m2/t**4) - t*kd*m2*(Y2-(Yequil(t2,m2)/Yequil(t,m1))*Y1)] 

# [-k*m1*(Y1*Y2-Yequil(t,m1)*Yequil(t2,m2))/t**2 + ks*m1*Yequil(t,m1)*(Y2-(Yequil(t2,m2)/Yequil(t,m1))*Y1)/t**2 + t*kd*m1*(Y2-(Yequil(t2,m2)/Yequil(t,m1))*Y1), -k*m2*(Y1*Y2-Yequil(t,m1)*Yequil(t2,m2))/t**2 - ks*m2*Yequil(t2,m2)*(Y2-(Yequil(t2,m2)/Yequil(t,m1))*Y1)/t**2 - t*kd*m2*(Y2-(Yequil(t2,m2)/Yequil(t,m1))*Y1)]


# YOU HAVE TO KEEP t2 AS THE INTEGRATING VARIABLE x OTHERWISE IF YOU PUT t1 and t2 FOR THE TWO DIFF. EQ.
# DO NOT WORK.

# %%
global ks
ks=1
global kd
kd=1

# %% [markdown]
# # k=fk(sigmav=3.4799974200853747e-06) ---> NO, I insert the whole formula inside, so also the integral
# # ks=fk(sigmav=2.696753758398017e-05) ---> NO, I insert the whole formula inside, so also the integral
# # kd=fk(sigmav=2.7897359041010654e-17)
#
# # These values integrated with the max step of 0.0002 gives the closest result so far of $\Omega h^2=0.15380237700000002$
#
# # With those values I got a decent result. The first one is the result of my python code "Coannihilation", where I have used the first approximation for the $\sigma_0$ substituted into the formula for $x_f$. Then I have performed the integral with the Bessel functions and the rest.. I have setted the Tfo2 as the reference temperature for computing the thermal average cross section.
#
# # The second is from my computation of the Scattering amplitude, with the logaritm and stuff. Seemed that even if it was $\sim 10^{-10}$ or $\sim 10^{-17}$ didn't change much..
#
# # The last one instead comes from the approximation paper.

# %% [markdown]
# # UPDATE 21/12/2022
# # I HAVE INSERT INSIDE THE DIFFERENTIAL EQUATION THE WHOLE FORMULA FOR THE $\langle \sigma v \rangle$ WITH THE INTEGRAL WITHOUT CHOOSING A VALUE FOR THE TEMPERATURE OF FREEZE-OUT.
# $$\langle \sigma v \rangle = \frac{1}{8 m_1^2m_2^2TK_2(m_1/T)K_2(m_2/T)} \int_{s_0}^{\infty} \sigma({s}-s_0)\sqrt{{s}}K_1(\sqrt{{s}}/T)ds$$
# # I HAVE USED THIS FORMULA INSIDE THE BOLTZMAN EQUATION.
# # THE TERMAL AVERAGE INTEGRAL IS PERFORMED IN $ds$ WHILE THE INTEGRATION OF THE DIFFERENTIAL EQUATION IS DONE IN $dx$ THAT DEPEND ON T AS $dx=m/dT$. SO THERE IS NO NEED TO PICK A CHOOSE FOR THE FREEZEOUT TEMPERATURE.
# # THIS HAS BEEN DONE FOR THE COANNIHILATION AND THE SCATTERING CROSS SECTION, BECAUSE I HAVE A NANALYTICAL VALUE FOR THEM. SHOULD BE PERFORMED ALSO FOR THE DECAY...... AND THEN WE ARE GOOD.
# # MOREOVER ACCORDING TO GORDAN THE $x_f$ FORMULA OF THE KOLB-TURNER IS NO LONGER VALID FOR THE iDM CASE. IN THIS WAY I AM ABLE TO SOLVE THE TWO DIFFERENTIAL EQUATION WITHOUT PICKING A VALUE FOR THE FREEZE-OUT BEFORE SOLVING IT.
# # In the following box is reported the equation that has been integrated

# %%
#************************************************************
# def odesiDM(t,z):
    #t2=t*(m2/m1)
    #Y1, Y2=z
    #return [-(quantity*(integrate.quad(lambda s_tilda: sigma(s_tilda)* (s_tilda-s0)* np.sqrt(s_tilda)* special.kv(1,np.sqrt(s_tilda)/(m1/t)), s0, np.inf )[0])*( 1/(8* m1**2 * m2**2  *(m1/t) *(special.kn(2,m1/(m1/t))*(special.kn(2,m2/(m1/t)))))) )*m1*(Y1*Y2-Yequil(t,m1)*Yequil(t2,m2))/t**2 + ((quantity*(integrate.quad(lambda s_tilda: sigma_SCAT(s_tilda)* (s_tilda-s0_SCAT)* np.sqrt(s_tilda)* special.kv(1,np.sqrt(s_tilda)/(m1/t)), s0_SCAT, np.inf )[0])*( 1/(8* m1**2 * mf**2  *(m1/t) *(special.kn(2,m1/(m1/t))*(special.kn(2,mf/(m1/t)))))) ))  *m1*Yequil(t,m1)*(Y2-(Yequil(t2,m2)/Yequil(t,m1))*Y1)/t**2 + t*kd*m1*(Y2-(Yequil(t2,m2)/Yequil(t,m1))*Y1),    -(quantity*(integrate.quad(lambda s_tilda: sigma(s_tilda)* (s_tilda-s0)* np.sqrt(s_tilda)* special.kv(1,np.sqrt(s_tilda)/(m1/t)), s0, np.inf )[0])*( 1/(8* m1**2 * m2**2  *(m1/t) *(special.kn(2,m1/(m1/t))*(special.kn(2,m2/(m1/t)))))) )*m2*(Y1*Y2-Yequil(t,m1)*Yequil(t2,m2))/t**2 -  (quantity*(integrate.quad(lambda s_tilda: sigma_SCAT(s_tilda)* (s_tilda-s0_SCAT)* np.sqrt(s_tilda)* special.kv(1,np.sqrt(s_tilda)/(m1/t)), s0_SCAT, np.inf )[0])*( 1/(8* m1**2 * mf**2  *(m1/t) *(special.kn(2,m1/(m1/t))*(special.kn(2,mf/(m1/t)))))) )  *m2*Yequil(t2,m2)*(Y2-(Yequil(t2,m2)/Yequil(t,m1))*Y1)/t**2 - t*kd*m2*(Y2-(Yequil(t2,m2)/Yequil(t,m1))*Y1)]       

    
    # I'll rewrite it here andando a capo:
    # #return [-(quantity*(integrate.quad(lambda s_tilda: sigma(s_tilda)* (s_tilda-s0)* np.sqrt(s_tilda)* 
    # special.kv(1,np.sqrt(s_tilda)/(m1/t)), s0, np.inf )[0])*( 1/(8* m1**2 * m2**2  *(m1/t) 
    # *(special.kn(2,m1/(m1/t))*(special.kn(2,m2/(m1/t)))))) )*m1*(Y1*Y2-Yequil(t,m1)*Yequil(t2,m2))/t**2 
    # + ((quantity*(integrate.quad(lambda s_tilda: sigma_SCAT(s_tilda)* (s_tilda-s0_SCAT)* np.sqrt(s_tilda)* 
    # special.kv(1,np.sqrt(s_tilda)/(m1/t)), s0_SCAT, np.inf )[0])*( 1/(8* m1**2 * mf**2  *(m1/t) 
    # *(special.kn(2,m1/(m1/t))*(special.kn(2,mf/(m1/t)))))) ))  *m1*Yequil(t,m1)*(Y2-(Yequil(t2,m2)/Yequil(t,m1))
    # *Y1)/t**2 + t*kd*m1*(Y2-(Yequil(t2,m2)/Yequil(t,m1))*Y1),    
    # -(quantity*(integrate.quad(lambda s_tilda: sigma(s_tilda)* (s_tilda-s0)* np.sqrt(s_tilda)* 
    # special.kv(1,np.sqrt(s_tilda)/(m1/t)), s0, np.inf )[0])*( 1/(8* m1**2 * m2**2  *(m1/t) 
    # *(special.kn(2,m1/(m1/t))*(special.kn(2,m2/(m1/t)))))) )*m2*(Y1*Y2-Yequil(t,m1)*Yequil(t2,m2))/t**2 -  
    # (quantity*(integrate.quad(lambda s_tilda: sigma_SCAT(s_tilda)* (s_tilda-s0_SCAT)* np.sqrt(s_tilda)* 
    # special.kv(1,np.sqrt(s_tilda)/(m1/t)), s0_SCAT, np.inf )[0])*( 1/(8* m1**2 * mf**2  *(m1/t) 
    # *(special.kn(2,m1/(m1/t))*(special.kn(2,mf/(m1/t)))))) )  *m2*Yequil(t2,m2)*(Y2-(Yequil(t2,m2)/Yequil(t,m1))
    # *Y1)/t**2 - t*kd*m2*(Y2-(Yequil(t2,m2)/Yequil(t,m1))*Y1)]       


    
    
# where the decay average cross section is:
#kd=fk(sigmav=2.7897359041010654e-17)
#************************************************************

# %% [markdown]
# # NEXT STEPS:
# # USE my CROSS SECTION FOR THE ANNIHILATION i.e. WITH A FACTOR 2 IN FRONT...
# # UNDERSTAND HOW TO GET AN ANALYTICAL FORMULA FOR THE DECAY CROSS SECTION AND PLUG IT IN, THEN.. DONE, THE WORK IS CONCLUDED AND THE RESULT SHOULD MATCH GORDAN'S PAPER (in principle).
#
#
# # NEXT NEXT STEP:
# # MODIFY THE BOLTZMAN EQUATION AGAIN AND PLUG INSIDE A NEW TERM FOR $\chi_1 \chi_1$ AND $\chi_2 \chi_2$ ANNIHILATION CROSS SECTION VIA THE SCALAR. THE SCALAR INTERACTION IS DIAGONAL, SO I NEED TO ADD AN EXTRA TERM TO THE BOLTZMAN EQUATION WHICH IS:
# $$- \frac{\lambda_A^{11,22}}{x^2} \Big[Y_{1,2}^2- (Y_{1,2}^0)^2 \Big]$$
# # AND THE BOLTZMAN EQUATION FOR iDM WITH SCALAR AND DARK PHOTON MEDIATORS BECOMES:
# $$ \frac{dY_{1,2}}{dx} = - \frac{\lambda_A^{1,2}}{x^2} \Big[ Y_1 Y_2 - Y_1^{(0)}Y_2^{(0)} \Big] - \frac{\lambda_A^{11,22}}{x^2} \Big[Y_{1,2}^2- (Y_{1,2}^0)^2 \Big] \pm x \lambda_D \Big( Y_2- \frac{Y_2^{(0)}}{Y_1^{(0)}}Y_1 \Big) \pm \frac{\lambda_S}{x^2}Y_f^{(0)} \Big( Y_2- \frac{Y_2^{(0)}}{Y_1^{(0)}}Y_1 \Big) $$

# %%
global k
k=1
fk=lambda sigmav: np.sqrt(np.pi*(Mp**2)/45)*sigmav*m2

# %%
# k=fk(sigmav=1.4101234699357789e-06)     # This is how it should be according to gordan's paper. 
# He has 1.7*1E-23 cm^3/s  and converting it into GeV-2 gives
#k=fk(sigmav=3.4799974200853747e-06)     # This is mine from Coannihilation

# k=fk(sigmav=7.502140332214219e-07)   This is the coannihilation <sigmav> computed in "approximation"




# I am considering just the first order cross section, without thermal average, because first
# approximation is fine according to the Gondolo and Gelmini paper

# due to the fact that the scattering cross section approximation depends on T^2 I have 
# inserted that dependence in the differential equation. 
# lambda=ks*mi*T**2 and all is divided for x**2, so T**2/x**2= mi**2/x**4!!!!
# 7.247433714688533e-05 * T**2
 
    
    
#ks=fk(sigmav=2.696753758398017e-05)        # My result with all set on Tfo2 but m1 and me
# ks=fk(sigmav=5.043658692012731e-17)       # My result with temperatures fucked up
# ks=fk(sigmav=5.560003416264709e-10)    # Gordan's result with the approximation



kd=fk(sigmav=2.7897359041010654e-17)    # My result
#kd=fk(sigmav=9.293719304636218e-17)    # Gordan's result with the approximation



#ks=fk(sigmav=2.95803358824373e-10)
#kd=fk(sigmav=4.9444454984331714e-17)



# k=fk(sigmav=1E-8)
# ks=fk(sigmav=1E-13)
# kd=fk(sigmav=1E-10)

# %%
t=np.logspace(np.log10(1),np.log10(60),100)
# t=np.linspace(1,100,1000)

# %%
#initial condition
x0=[Yequilibrium(t[0],m1),Yequilibrium(t[0],m2)]
x0
# Out:
# [array(0.00744837), array(0.00686955)]

# %%
#inte=integrate.odeint(odesiDM,x0,t,hmax=0.003)
inte=integrate.solve_ivp(odesiDM, [1,60],x0, method="Radau",dense_output=True,t_eval=t, max_step=0.003)

# %%
# IS ARRIVED AD CONVERGENCE!!!!! AND WORKS!!!
# inte=integrate.solve_ivp(odesiDM, [1,100],x0, method="Radau",dense_output=True,t_eval=t, max_step=0.0004)

# %%
inte.y
# Out:
# array([[7.44836679e-03, 7.69171078e-03, 7.92764585e-03, 8.15431291e-03,
#         8.36977733e-03, 8.57204469e-03, 8.75907964e-03, 8.92882757e-03,
#         9.07923929e-03, 9.20829815e-03, 9.31404995e-03, 9.39463503e-03,
#         9.44832162e-03, 9.47354188e-03, 9.46892679e-03, 9.43334235e-03,
#         9.36594928e-03, 9.26611120e-03, 9.13367446e-03, 8.96874477e-03,
#         8.77183333e-03, 8.54384722e-03, 8.28609733e-03, 8.00029878e-03,
#         7.68833046e-03, 7.35337557e-03, 6.99757684e-03, 6.84555192e-03,
#         6.39883608e-03, 5.94968136e-03, 5.50148288e-03, 5.05764641e-03,
#         4.62152711e-03, 4.19635786e-03, 3.78518275e-03, 3.39079351e-03,
#         3.01567165e-03, 2.66193847e-03, 2.33131504e-03, 2.02509357e-03,
#         1.74412156e-03, 1.48879933e-03, 1.25909111e-03, 1.05454918e-03,
#         8.74349968e-04, 7.17340373e-04, 5.82092268e-04, 4.66962513e-04,
#         3.70155721e-04, 2.89787142e-04, 2.23942601e-04, 1.70733415e-04,
# ...

# %%
print(len(inte.y))
# Out:
# 2

# %%
Y1=inte.y[0]
Y2=inte.y[1]

# %%
O=np.logspace(np.log10(1),np.log10(60),100)
O2=O*((m1+delta)/m1)

xx=np.logspace(np.log10(1),np.log10(100),1000)
plt.plot(x2, Yequilibrium(x1,m1),'b--',label=r'$Y_{\rm eq1}$')
plt.plot(x2, Yequilibrium(x2,m2),'k--',label=r'$Y_{\rm eq2}$')

plt.plot(O2,Y1,'b',label=r'$Y_{1}$')
plt.plot(O2,Y2,'k',label=r'$Y_{2}$')

#plt.hlines(7.8*1E-12,1,1000,linestyles='-',color='g',lw=2,label='$Y_0$')


plt.yscale('log')

#plt.ylim(1E-14,1)
plt.ylim(1E-14,3*1E-2)
#plt.xlim(1,1000)
plt.xlim(1,60)
plt.xlabel('$x_2 = m_2/T$', size= 15)
plt.ylabel('$Y=n/s$', size= 15)
plt.title('$m_1 = 0.05$ GeV', size= 15)
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# $$\Omega_{\chi}h^2= \frac{\rho_{\chi}^0h^2}{\rho_c^0}= \frac{m_{\chi}s_0 Y_0 h^2}{\rho_c^0} \ \ \ \ \ \ \ \ \ \  s_0= \frac{2 \pi^2}{45}g_{*s}(T_{\gamma}) T_{\gamma}^3$$
#
# $$\frac{s_0 h^2}{\rho_c^0}= \frac{3120 \times 0.71^2}{1.05375 \times 10^{-5}} \approx 1.5 \times 10^{8}$$
#
# $$\Omega_{\chi}h^2= 1.5 \times 10^{8} m_\chi Y_0 (c^2/ \text{GeV})= 1.5 \times 10^{10} Y_0 \Big( \frac{m_\chi}{100 \text{GeV}/c^2} \Big)\rightarrow = 0.118$$

# %%
# TAKEN FROM THE INTEGRAL, THE VALUE OF Y_0 at infinity is:
Yzero=3.27789491e-08
#Yzero=1.5028748e-08       # Round number that whould give the right abundance
Omegah2=1.5*(1E+10)*Yzero*(m1/100)
Omegah2


# IT'S ALMOST OKAY.
# INSTEAD OF 6.46014066e-08  should be 1.46014066e-08
# Out:
# 0.24584211825

# %% [markdown]
# # Again from Kolb Turner
# # $Y_{\infty}=\frac{3.79(n+1)x_f^{n+1}}{(g_{*s}/g_*^{1/2}) m_{Pl} \, m \, \sigma_0}$ That then became into $\Omega h^2=\frac{1.07 \times 10^9 x_f}{(g_{*s}/g_*^{1/2})M_{Pl} \sigma_0}$

# %%
Yinfty= (3.79*23.2)/((10.44692737/np.sqrt(10.44692737))*Mp*m1*1.4101234699357789e-06)
Yinfty
# Out:
# 3.16261212162252e-11

# %%
Omegah2= (1.07*(1E+9)*23.3)/(np.sqrt(10.44692737)*Mp*1.4101234699357789e-06)
Omegah2
# Out:
# 0.0004483616299936941

# %%
t=np.linspace(1,100,1000)
plt.plot(x2,inte.sol(t).T)


plt.yscale('log')
plt.xscale('log')

#plt.ylim(1E-14,1)
plt.ylim(1E-14,1E-2)
#plt.xlim(1,1000)
plt.xlim(1,60)
plt.xlabel('$x_2 = m_2/T$', size= 15)
plt.ylabel('$Y$', size= 15)
plt.title('$m = 0.05$ GeV', size= 15)
plt.legend()
plt.grid()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
def lotkavolterra(t, z, a, b, c, d):
    x, y = z
    return [a*x - b*x*y, -c*y + d*x*y]

# %%
sol = integrate.solve_ivp(lotkavolterra, [0, 15], [10,5], args=(1.5, 1, 3, 1),dense_output=True)

# %%
t = np.linspace(0, 15, 300)
sol.sol(t).T
# Out:
# array([[10.        ,  5.        ],
#        [ 8.02362436,  6.77048951],
#        [ 5.92551922,  8.25309726],
#        [ 4.10678303,  9.13129277],
#        [ 2.76415766,  9.33366605],
#        [ 1.88109711,  9.00596495],
#        [ 1.30054325,  8.39207087],
#        [ 0.92889008,  7.63786532],
#        [ 0.69678045,  6.84146983],
#        [ 0.54228074,  6.07076647],
#        [ 0.43770026,  5.35281443],
#        [ 0.36670431,  4.69857008],
#        [ 0.31717655,  4.11160011],
#        [ 0.28204036,  3.59028556],
#        [ 0.25679653,  3.13065527],
#        [ 0.23900475,  2.72685389],
#        [ 0.22671624,  2.37327072],
#        [ 0.21881651,  2.06447206],
#        [ 0.21438365,  1.79534694],
#        [ 0.21266044,  1.56112369],
#        [ 0.21307542,  1.35726433],
#        [ 0.21543789,  1.17979143],
#        [ 0.21972646,  1.0256731 ],
#        [ 0.22588775,  0.89209875],
#        [ 0.23383348,  0.7764488 ],
#        [ 0.24344039,  0.67629468],
#        [ 0.2545503 ,  0.58939883],
# ...

# %%
t = np.linspace(0, 15, 300)
z = sol.sol(t)
plt.plot(t, z.T)
plt.xlabel('t')
plt.legend(['x', 'y'], shadow=True)
plt.title('Lotka-Volterra System')
plt.show()
