# %%
import matplotlib.pyplot as plt
import csv
import numpy as np

# %%
X, Y = np.loadtxt('dofdata/gstarSteigmanQCDFine.txt', delimiter=' ', unpack=True)

# %%
X
# Out:
# array([1.03106512e-03, 1.14408637e-03, 1.27728776e-03, 1.39152116e-03,
#        1.51597094e-03, 1.71330725e-03, 1.91278074e-03, 2.10950564e-03,
#        2.35510692e-03, 2.62930258e-03, 2.95343708e-03, 3.37898712e-03,
#        3.77238904e-03, 4.05978561e-03, 4.50480316e-03, 4.87775141e-03,
#        5.18551448e-03, 5.58056893e-03, 5.89648836e-03, 6.54283796e-03,
#        7.26003783e-03, 7.76547973e-03, 8.40837621e-03, 9.10449745e-03,
#        9.73835014e-03, 1.02268794e-02, 1.08058293e-02, 1.17004334e-02,
#        1.28250844e-02, 1.38868606e-02, 1.54090830e-02, 1.66847859e-02,
#        1.87416488e-02, 2.05431045e-02, 2.26559134e-02, 2.48336101e-02,
#        2.68895604e-02, 2.92944107e-02, 3.17196663e-02, 3.47685750e-02,
#        3.78780797e-02, 4.17737491e-02, 4.57890608e-02, 5.04983556e-02,
#        5.50146430e-02, 6.03026755e-02, 6.56958058e-02, 7.15712672e-02,
#        7.74965825e-02, 8.28918739e-02, 8.92069278e-02, 9.60030892e-02,
# ...

# %%
Y
# Out:
# array([ 10.39106145,  10.39106145,  10.39106145,  10.44692737,
#         10.44692737,  10.44692737,  10.44692737,  10.44692737,
#         10.44692737,  10.5027933 ,  10.5027933 ,  10.5027933 ,
#         10.55865922,  10.55865922,  10.55865922,  10.61452514,
#         10.61452514,  10.61452514,  10.61452514,  10.61452514,
#         10.67039106,  10.61452514,  10.61452514,  10.61452514,
#         10.61452514,  10.61452514,  10.61452514,  10.61452514,
#         10.67039106,  10.67039106,  10.67039106,  10.72625698,
#         11.00558659,  11.2849162 ,  11.56424581,  11.84357542,
#         12.12290503,  12.34636872,  12.68156425,  13.12849162,
#         13.46368715,  13.79888268,  14.18994413,  14.63687151,
#         14.91620112,  15.30726257,  15.58659218,  15.92178771,
#         16.31284916,  16.53631285,  16.70391061,  17.15083799,
#         17.48603352,  17.98882682,  18.43575419,  18.93854749,
#         19.32960894,  20.        ,  20.55865922,  21.11731844,
# ...

# %%
print(len(X))
print(len(X))
# Out:
# 251
# 251

# %%
plt.plot(X, Y, label='g_star Steigman QCD Fine')
plt.title('g_star Steigman QCD Fine')
plt.xlabel('T [GeV]')
plt.ylabel('g_star')
plt.xscale('log')
plt.yscale('log')
plt.show()

# %%
x,y = np.loadtxt('dofdata/gstarSdata.txt', delimiter=' ', unpack=True)

# %%
plt.plot(x, y)
plt.title('g_star S data')
plt.xlabel('T [GeV]')
plt.ylabel('g_star S')
plt.xscale('log')
plt.show()

# %%
x1=x*1000

# %%
plt.plot(x, y, label='g_star S data')
#plt.plot(x1, y, label='g_star S data * 100')
plt.plot(X, Y, label='g_star Steigman QCD Fine')
plt.title('g_star S data')
plt.xlabel('T [GeV]')
plt.ylabel('g_star S')
plt.xscale('log')
plt.yscale('log')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ![g_star.png](attachment:g_star.png)
